# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import BallTree

EARTH_RADIUS_M = 6371000

# -----------------------------
# Configuration
# -----------------------------
CROSSWALK_CSV = '../cw.csv'
ACCIDENT_CSV  = '../acc_hotspot.csv'

RADIUS_M = 500  # meters
OUT_CW_ACC_MAP = 'cw_acc_map_500m.csv'          # (NEW) 매핑 테이블

# -----------------------------
# Load
# -----------------------------
cw = pd.read_csv(CROSSWALK_CSV)
acc = pd.read_csv(ACCIDENT_CSV)

# 좌표 컬럼명은 네 데이터에 맞게 유지(노트북 기존 로직 그대로 쓰면 됨)
cw_valid = cw.dropna(subset=['crosswalk_lat','crosswalk_lon']).copy()
acc_valid = acc.dropna(subset=['accident_lat','accident_lon']).copy()

# radians (lat, lon)
cw_rad  = np.radians(cw_valid[['crosswalk_lat','crosswalk_lon']].to_numpy())
acc_rad = np.radians(acc_valid[['accident_lat','accident_lon']].to_numpy())

# BallTree (haversine)
tree = BallTree(acc_rad, metric='haversine')
radius_rad = RADIUS_M / EARTH_RADIUS_M

# -----------------------------
# (A) 500m 내 "모든 사고" 매핑 테이블 만들기  ✅ 핵심
# -----------------------------
inds, dists = tree.query_radius(cw_rad, r=radius_rad, return_distance=True, sort_results=True)

cw_idx = np.repeat(np.arange(len(cw_valid)), [len(x) for x in inds])
acc_idx = np.concatenate(inds) if len(cw_idx) else np.array([], dtype=int)
dist_m  = (np.concatenate(dists) * EARTH_RADIUS_M) if len(cw_idx) else np.array([], dtype=float)

map_df = pd.DataFrame({
    'cw_idx': cw_idx,
    'acc_idx': acc_idx,
    'distance_m': dist_m
})

# 원본 컬럼 붙이기 (prefix로 충돌 방지)
cw_pref  = cw_valid.reset_index(drop=True).add_prefix('cw_')
acc_pref = acc_valid.reset_index(drop=True).add_prefix('acc_')

cw_acc_map = (
    map_df
    .merge(cw_pref, left_on='cw_idx', right_index=True, how='left')
    .merge(acc_pref, left_on='acc_idx', right_index=True, how='left')
    .drop(columns=['cw_idx','acc_idx'])
)

cw_acc_map.to_csv(OUT_CW_ACC_MAP, index=False, encoding='utf-8-sig')
print("saved:", OUT_CW_ACC_MAP, "rows:", len(cw_acc_map))
# Out:
# saved: cw_acc_map_500m.csv rows: 964240
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 77
#      74 for col in sum_cols:
#      75     if col in acc_valid.columns:
#      76         cw_out[f'sum_{col}_within_{RADIUS_M}m'] = [
# ---> 77             acc_valid.iloc[x][col].fillna(0).sum() if len(x) else 0
#      78             for x in inds
#      79         ]
#      81 # nearest도 유지 가능
#      82 dist1, idx1 = tree.query(cw_rad, k=1)
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\pandas\core\indexing.py:1744, in _iLocIndexer._getitem_axis(self, key, axis)
#    1742 # a list of integers
#    1743 elif is_list_like_indexer(key):
# -> 1744     return self._get_list_axis(key, axis=axis)
#    1746 # a single integer
#    1747 else:
#    1748     key = item_from_zerodim(key)
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\pandas\core\indexing.py:1715, in _iLocIndexer._get_list_axis(self, key, axis)
#    1698 """
#    1699 Return Series values by list or array of integers.
#    1700
#    (...)   1712 `axis` can only be zero.
#    1713 """
#    1714 try:
# -> 1715     return self.obj._take_with_is_copy(key, axis=axis)
#    1716 except IndexError as err:
#    1717     # re-raise with different error message, e.g. test_getitem_ndarray_3d
#    1718     raise IndexError("positional indexers are out-of-bounds") from err
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\pandas\core\generic.py:4175, in NDFrame._take_with_is_copy(self, indices, axis)
#    4164 @final
#    4165 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4166     """
#    4167     Internal version of the `take` method that sets the `_is_copy`
#    4168     attribute to keep track of the parent dataframe (using in indexing
#    (...)   4173     See the docstring of `take` for full explanation of the parameters.
#    4174     """
# -> 4175     result = self.take(indices=indices, axis=axis)
#    4176     # Maybe set copy if we didn't actually change the index.
#    4177     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\pandas\core\generic.py:4155, in NDFrame.take(self, indices, axis, **kwargs)
#    4150     # We can get here with a slice via DataFrame.__getitem__
#    4151     indices = np.arange(
#    4152         indices.start, indices.stop, indices.step, dtype=np.intp
#    4153     )
# -> 4155 new_data = self._mgr.take(
#    4156     indices,
#    4157     axis=self._get_block_manager_axis(axis),
#    4158     verify=True,
#    4159 )
#    4160 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4161     self, method="take"
#    4162 )
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\pandas\core\internals\managers.py:913, in BaseBlockManager.take(self, indexer, axis, verify)
#     910 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     912 new_labels = self.axes[axis].take(indexer)
# --> 913 return self.reindex_indexer(
#     914     new_axis=new_labels,
#     915     indexer=indexer,
#     916     axis=axis,
#     917     allow_dups=True,
#     918     copy=None,
#     919 )
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\pandas\core\internals\managers.py:707, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     699     new_blocks = self._slice_take_blocks_ax0(
#     700         indexer,
#     701         fill_value=fill_value,
#     702         only_slice=only_slice,
#     703         use_na_proxy=use_na_proxy,
#     704     )
#     705 else:
#     706     new_blocks = [
# --> 707         blk.take_nd(
#     708             indexer,
#     709             axis=1,
#     710             fill_value=(
#     711                 fill_value if fill_value is not None else blk.fill_value
#     712             ),
#     713         )
#     714         for blk in self.blocks
#     715     ]
#     717 new_axes = list(self.axes)
#     718 new_axes[axis] = new_axis
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\pandas\core\internals\blocks.py:1373, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1370     allow_fill = True
#    1372 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1373 new_values = algos.take_nd(
#    1374     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1375 )
#    1377 # Called from three places in managers, all of which satisfy
#    1378 #  these assertions
#    1379 if isinstance(self, ExtensionBlock):
#    1380     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1381     #  algos.take_nd call above.
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\pandas\core\array_algos\take.py:162, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
# --> 162 func(arr, indexer, out, fill_value)
#     164 if flip_order:
#     165     out = out.T
#
# KeyboardInterrupt:
